# %%
import pandas as pd

# %%
dataset=pd.read_excel("C:/Users/pc/Downloads/pokemon_data.xlsx")

# %%
## read heads
dataset.columns
## read each columns
#dataset["Name"][0:5]
dataset.Name
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %%
#selection
dataset["Name"]
#can select one or multiple rows using their numbers
dataset[1:3]
#can select any slice of the table using a coloumn label and row number using loc
dataset.loc[1:3,["Name"]]
#can select using iloc
dataset.iloc[0:4]
dataset.iloc[0:4,1:4]
# Out:
#                     Name Type 1  Type 2
# 0              Bulbasaur  Grass  Poison
# 1                Ivysaur  Grass  Poison
# 2               Venusaur  Grass  Poison
# 3  VenusaurMega Venusaur  Grass  Poison

# %%
#filtering
#select the dataset whose Type 1 is grass 
dataset[dataset["Type 1"]=="Grass"]
#new_dataset=dataset[(dataset['Type 1'] == 'Grass') & (dataset['Type 2'] == 'Poison') & (dataset['HP'] > 70)]
#print(new_dataset)
#select the dataset HP>60
dataset[dataset["HP"]>60]
# Out:
#        #                       Name   Type 1  Type 2   HP  Attack  Defense  \
# 2      3                   Venusaur    Grass  Poison   80      82       83
# 3      3      VenusaurMega Venusaur    Grass  Poison   80     100      123
# 6      6                  Charizard     Fire  Flying   78      84       78
# 7      6  CharizardMega Charizard X     Fire  Dragon   78     130      111
# 8      6  CharizardMega Charizard Y     Fire  Flying   78     104       78
# ..   ...                        ...      ...     ...  ...     ...      ...
# 793  717                    Yveltal     Dark  Flying  126     131       95
# 794  718           Zygarde50% Forme   Dragon  Ground  108     100      121
# 797  720        HoopaHoopa Confined  Psychic   Ghost   80     110       60
# 798  720         HoopaHoopa Unbound  Psychic    Dark   80     160       60
# 799  721                  Volcanion     Fire   Water   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# ### Dealing with Missing Values
# Many datasets you’ll deal with in your data science journey will have missing values. Let’s say our data frame has a missing value:

# %%
dataset.describe()
#check is na in dataset
dataset.isna()
dataset.isna().sum()
#handing missing dataset
dataset.dropna()
#another way fillna
dataset.fillna("Poision")
# Out:
#        #                   Name   Type 1   Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass   Poison  45      49       49
# 1      2                Ivysaur    Grass   Poison  60      62       63
# 2      3               Venusaur    Grass   Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass   Poison  80     100      123
# 4      4             Charmander     Fire  Poision  39      52       43
# ..   ...                    ...      ...      ...  ..     ...      ...
# 795  719                Diancie     Rock    Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock    Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic    Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic     Dark  80     160       60
# 799  721              Volcanion     Fire    Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %% [markdown]
# ## Grouping
# Things start to get really interesting when you start grouping rows with certain criteria and aggregating their data . for example let's group our dataset by Type 1

# %%
dataset.groupby("Type 1").sum()
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_23020\91017679.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   dataset.groupby("Type 1").sum()
#               #    HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  \
# Type 1
# Bug       23080  3925    4897     4880     3717     4471   4256         222
# Dark      14302  2071    2740     2177     2314     2155   2361         125
# Dragon    15180  2666    3588     2764     3099     2843   2657         124
# Electric  15994  2631    3040     2917     3961     3243   3718         144
# Fairy      7642  1260    1046     1117     1335     1440    826          70
# Fighting   9824  1886    2613     1780     1434     1747   1784          91
# Fire      17025  3635    4408     3524     4627     3755   3871         167
# ...

# %% [markdown]
# ### Creating New Columns from Existing Columns
# Often in the data analysis process, we find ourselves needing to create new columns from existing ones. Pandas makes this a breeze.
# for example create row of defence:attack

# %%
import numpy as np
dataset.loc[:,"D"]=np.array(5)*len(dataset)

# %%
dataset.head()

dataset["Avg Defense"]=dataset["Defense"]/dataset["Attack"]

# %%
dataset.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary     D  Avg Defense
# 0       65     45           1      False  4000     1.000000
# 1       80     60           1      False  4000     1.016129
# 2      100     80           1      False  4000     1.012195
# 3      120     80           1      False  4000     1.230000
# 4       50     65           1      False  4000     0.826923
